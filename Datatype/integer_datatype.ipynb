# %% [markdown]
# data types

# %%
c=166
print(c)
# Out:
# 166

# %%
i=[1,2,3,4,5]
print ("sum of 5 num= ", sum(i))
# Out:
# sum of 5 num=  15

# %%
# Question 1: Calculate the product of first 10 natural numbers
product=1
for i in range (1,11):   
    product*=i
print("product of first 10 natural num = ",product)
# Out:
# product of first 10 natural num =  3628800

# %%
# Question 3: Calculate the square of 25

a=25
square=a*a
print("square of 25 is ",square)
# Out:
# square of 25 is  625

# %%
#print("\nQuestion 5: Calculate the sum of digits in number 12345")
 
num=12345
s=0
while num>0:
      s= s+ (num%10)
      num = int((num)/10)
      print (s,num)
print("sum of the given number = ",s)
# Out:
# 5 1234
# 9 123
# 12 12
# 14 1
# 15 0
# sum of the given number =  15

# %%
# Question 6: Check if 97 is a prime number
 
n=97
if n<0:
   print("its not a prime num")
else :
   for i in range(2,97):
   if n % i==0;
# Out:
#   Cell In[110], line 8
#     if n % i==0;
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7

# %%
#print("\nQuestion 7: Find the factorial of 8")

n=8
factorial=1
for i in range (1,9):
   factorial*=i
print("the factorial of 8 is ", factorial)
# Out:
# the factorial of 8 is  40320

# %%
# Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56
num = [15,23,31,42,56] 
s= sum(num)
print(s)
#print(len(num))
#print(sum(num)/len(num))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 3
#       1 # Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56
#       2 num = [15,23,31,42,56]
# ----> 3 s= sum(num)
#       4 print(s)
#       5 #print(len(num))
#       6 #print(sum(num)/len(num))
#
# TypeError: 'float' object is not callable

# %%
# Question 9: Find the greatest common divisor (GCD) of 48 and 36

a=48
b=36
while b>0 :
    r=a%b
    a=b
    b=r
print("gcd is ",a)
# Out:
# gcd is  12

# %%
# Question 8: Calculate the average of numbers: 15, 23, 31, 42, 56

list = [15,23,31,42,56]
s=0
for i in range(len(list)):
    s+=list[i]
    l=len(list)
print("the sum of list ",s)
print("the length of list",l)
avg=s/l
print("the avg of list is ",avg)
# Out:
# the sum of list  167
# the length of list 5
# the avg of list is  33.4

# %%
# Question 10: Calculate the sum of first 20 odd numbers

num=1
s=0
for i in range(1,21):
   s += num
   num+=2
print("the sum of first 20 odd numbers ",s)
# Out:
# the sum of first 20 odd numbers  400

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 2
#       1 i=[1,2,3,4,5]
# ----> 2 print("sum of 5 num= ",sum(i))
#
# TypeError: 'float' object is not callable
