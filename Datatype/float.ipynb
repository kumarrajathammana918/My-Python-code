# %%
floatdatatype
# Out:
# hell

# %%
# Question 1: Calculate the average of 3.14, 2.718, 1.618, 0.577

a=[3.14, 2.718, 1.618, 0.577]
(avg) = sum(a)/len(a)
print(avg)
# Out:
# 2.01325

# %%
# Question 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)
 
f=98.6
c=(f-32)*5/9
print("the converted celcius ",c)
# Out:
# the converted celcius  37.0

# %%
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years

p=1000
t=3
r=5.5
c=p*t*r/100
print("the compound intrest= ",c)
# Out:
# the compound intrest=  165.0

# %%
t
# Out:
# 3

# %%
## 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2")
import math
a=3.5
b=4.2
h= math.sqrt(a**2 +b**2)
print(h)
# Out:
# 5.4671747731346585

# %%
# Question 5: Calculate the volume of a sphere with radius 7.8

import math
r=7.8
a=4/3*math.pi*r**3
print("the volume of sphere ",a)
# Out:
# the volume of sphere  1987.798769261791

# %%
# Question 6: Round 3.14159 to 3 decimal places

# %%
# Question 7: Calculate the percentage: 45 out of 67
a =45
b=67
percentage=(a/100)*b
print(percentage)
# Out:
# 30.150000000000002

# %%
# Question 8: Find the square root of 23.456
 
import math
a=23.456
b=math.sqrt(a)
print(b)
# Out:
# 4.843139477652899

# %%
# Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years
p=2500
r=6.5
t=2.5
s=(p*t*r)/100
print(s)
# Out:
# 406.25

# %%
a=["kumar","raj","ram","jdhj"]
print(a)
# Out:
# ['kumar', 'raj', 'ram', 'jdhj']

# %%
a[2:-1]
# Out:
# ['ram']

# %%
a=["kumar","raj","ram","jdhj"]
a.append("000raja")

# %%
e=[]
print(e)
e.append("*")
print(e)
e.append("**")
print(e)

e.append("***")
print(e)

e.append("****")
print(e)

e.append("*****")
print(e)

e.append("******")
print(e)
# Out:
# []
# ['*']
# ['*', '**']
# ['*', '**', '***']
# ['*', '**', '***', '****']
# ['*', '**', '***', '****', '*****']
# ['*', '**', '***', '****', '*****', '******']

# %%
a=[10,20]
a.append(a[0]-a[1])

# %%
a
# Out:
# [10, 20, -10]

# %%
a.append(a[0]- 1)

# %%
a
# Out:
# [10, 20, -10, 9]

# %%
print(t)
# Out:
# 3

# %%
a=1
b=5
c=a+b

# %%
print(c)
# Out:
# 6
